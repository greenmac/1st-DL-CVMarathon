# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'Facial_Keypoints_Detection/training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# ==========================] - 6s 3ms/step - loss: 2.4557e-04 - val_loss: 8.7143e-04
#
# Epoch 00031: val_loss did not improve from 0.00082
# Epoch 32/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2877e-04 - val_loss: 9.0669e-04
#
# Epoch 00032: val_loss did not improve from 0.00082
# Epoch 33/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.4092e-04 - val_loss: 8.3873e-04
#
# Epoch 00033: val_loss did not improve from 0.00082
# Epoch 34/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.3104e-04 - val_loss: 8.3353e-04
#
# Epoch 00034: val_loss did not improve from 0.00082
# Epoch 35/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 2.1798e-04 - val_loss: 7.8689e-04
#
# Epoch 00035: val_loss improved from 0.00082 to 0.00079, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 11s 7ms/step - loss: 2.1699e-04 - val_loss: 8.0630e-04
#
# Epoch 00036: val_loss did not improve from 0.00079
# Epoch 37/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1632e-04 - val_loss: 8.0081e-04
#
# Epoch 00037: val_loss did not improve from 0.00079
# Epoch 38/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1053e-04 - val_loss: 8.1088e-04
#
# Epoch 00038: val_loss did not improve from 0.00079
# Epoch 39/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0415e-04 - val_loss: 8.0722e-04
#
# Epoch 00039: val_loss did not improve from 0.00079
# Epoch 40/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0204e-04 - val_loss: 8.2751e-04
#
# Epoch 00040: val_loss did not improve from 0.00079
# Epoch 41/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9734e-04 - val_loss: 8.2857e-04
#
# Epoch 00041: val_loss did not improve from 0.00079
# Epoch 42/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0364e-04 - val_loss: 8.5973e-04
#
# Epoch 00042: val_loss did not improve from 0.00079
# Epoch 43/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9982e-04 - val_loss: 7.9993e-04
#
# Epoch 00043: val_loss did not improve from 0.00079
# Epoch 44/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9799e-04 - val_loss: 8.4101e-04
#
# Epoch 00044: val_loss did not improve from 0.00079
# Epoch 45/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8933e-04 - val_loss: 7.8194e-04
#
# Epoch 00045: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 46/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8714e-04 - val_loss: 8.3107e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7749e-04 - val_loss: 8.4814e-04
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8769e-04 - val_loss: 7.8519e-04
#
# Epoch 00048: val_loss did not improve from 0.00078
# Epoch 49/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8066e-04 - val_loss: 8.1572e-04
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8268e-04 - val_loss: 8.3465e-04
#
# Epoch 00050: val_loss did not improve from 0.00078
# Epoch 51/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7578e-04 - val_loss: 7.7582e-04
#
# Epoch 00051: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7035e-04 - val_loss: 8.0296e-04
#
# Epoch 00052: val_loss did not improve from 0.00078
# Epoch 53/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7312e-04 - val_loss: 7.7160e-04
#
# Epoch 00053: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6413e-04 - val_loss: 7.9021e-04
#
# Epoch 00054: val_loss did not improve from 0.00077
# Epoch 55/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6326e-04 - val_loss: 8.1586e-04
#
# Epoch 00055: val_loss did not improve from 0.00077
# Epoch 56/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.6846e-04 - val_loss: 8.7300e-04
#
# Epoch 00056: val_loss did not improve from 0.00077
# Epoch 57/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6309e-04 - val_loss: 8.0178e-04
#
# Epoch 00057: val_loss did not improve from 0.00077
# Epoch 58/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6328e-04 - val_loss: 8.3937e-04
#
# Epoch 00058: val_loss did not improve from 0.00077
# Epoch 59/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6141e-04 - val_loss: 7.7082e-04
#
# Epoch 00059: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6491e-04 - val_loss: 7.9408e-04
#
# Epoch 00060: val_loss did not improve from 0.00077
# Epoch 61/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.6061e-04 - val_loss: 8.0996e-04
#
# Epoch 00061: val_loss did not improve from 0.00077
# Epoch 62/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5794e-04 - val_loss: 7.8224e-04
#
# Epoch 00062: val_loss did not improve from 0.00077
# Epoch 63/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 1.5480e-04 - val_loss: 7.8268e-04
#
# Epoch 00063: val_loss did not improve from 0.00077
# Epoch 64/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5244e-04 - val_loss: 8.0395e-04
#
# Epoch 00064: val_loss did not improve from 0.00077
# Epoch 65/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5364e-04 - val_loss: 7.6406e-04
#
# Epoch 00065: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 66/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4897e-04 - val_loss: 8.0697e-04
#
# Epoch 00066: val_loss did not improve from 0.00076
# Epoch 67/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4393e-04 - val_loss: 7.8838e-04
#
# Epoch 00067: val_loss did not improve from 0.00076
# Epoch 68/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4863e-04 - val_loss: 8.3086e-04
#
# Epoch 00068: val_loss did not improve from 0.00076
# Epoch 69/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4569e-04 - val_loss: 8.1110e-04
#
# Epoch 00069: val_loss did not improve from 0.00076
# Epoch 70/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4630e-04 - val_loss: 8.2767e-04
#
# Epoch 00070: val_loss did not improve from 0.00076
# Epoch 71/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4310e-04 - val_loss: 7.7498e-04
#
# Epoch 00071: val_loss did not improve from 0.00076
# Epoch 72/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3618e-04 - val_loss: 8.3503e-04
#
# Epoch 00072: val_loss did not improve from 0.00076
# Epoch 73/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4093e-04 - val_loss: 8.3391e-04
#
# Epoch 00073: val_loss did not improve from 0.00076
# Epoch 74/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3795e-04 - val_loss: 7.9412e-04
#
# Epoch 00074: val_loss did not improve from 0.00076
# Epoch 75/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3492e-04 - val_loss: 8.1893e-04
#
# Epoch 00075: val_loss did not improve from 0.00076
# Epoch 76/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3848e-04 - val_loss: 7.9709e-04
#
# Epoch 00076: val_loss did not improve from 0.00076
# Epoch 77/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3843e-04 - val_loss: 7.6347e-04
#
# Epoch 00077: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 78/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3737e-04 - val_loss: 7.7278e-04
#
# Epoch 00078: val_loss did not improve from 0.00076
# Epoch 79/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2740e-04 - val_loss: 7.8898e-04
#
# Epoch 00079: val_loss did not improve from 0.00076
# Epoch 80/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3308e-04 - val_loss: 7.7299e-04
#
# Epoch 00080: val_loss did not improve from 0.00076
# Epoch 81/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3300e-04 - val_loss: 8.0905e-04
#
# Epoch 00081: val_loss did not improve from 0.00076
# Epoch 82/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3155e-04 - val_loss: 7.7753e-04
#
# Epoch 00082: val_loss did not improve from 0.00076
# Epoch 83/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2703e-04 - val_loss: 8.0127e-04
#
# Epoch 00083: val_loss did not improve from 0.00076
# Epoch 84/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2260e-04 - val_loss: 7.7123e-04
#
# Epoch 00084: val_loss did not improve from 0.00076
# Epoch 85/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3048e-04 - val_loss: 7.8853e-04
#
# Epoch 00085: val_loss did not improve from 0.00076
# Epoch 86/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2466e-04 - val_loss: 7.8154e-04
#
# Epoch 00086: val_loss did not improve from 0.00076
# Epoch 87/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2720e-04 - val_loss: 7.9443e-04
#
# Epoch 00087: val_loss did not improve from 0.00076
# Epoch 88/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2426e-04 - val_loss: 7.9343e-04
#
# Epoch 00088: val_loss did not improve from 0.00076
# Epoch 89/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1874e-04 - val_loss: 8.0999e-04
#
# Epoch 00089: val_loss did not improve from 0.00076
# Epoch 90/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2299e-04 - val_loss: 8.3685e-04
#
# Epoch 00090: val_loss did not improve from 0.00076
# Epoch 91/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2437e-04 - val_loss: 7.9085e-04
#
# Epoch 00091: val_loss did not improve from 0.00076
# Epoch 92/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1724e-04 - val_loss: 8.2026e-04
#
# Epoch 00092: val_loss did not improve from 0.00076
# Epoch 93/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 1.2208e-04 - val_loss: 8.5354e-04
#
# Epoch 00093: val_loss did not improve from 0.00076
# Epoch 94/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2099e-04 - val_loss: 8.1978e-04
#
# Epoch 00094: val_loss did not improve from 0.00076
# Epoch 95/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2097e-04 - val_loss: 8.4341e-04
#
# Epoch 00095: val_loss did not improve from 0.00076
# Epoch 96/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1813e-04 - val_loss: 7.7066e-04
#
# Epoch 00096: val_loss did not improve from 0.00076
# Epoch 97/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1589e-04 - val_loss: 7.5403e-04
#
# Epoch 00097: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 98/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1226e-04 - val_loss: 7.8488e-04
#
# Epoch 00098: val_loss did not improve from 0.00075
# Epoch 99/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1039e-04 - val_loss: 7.8173e-04
#
# Epoch 00099: val_loss did not improve from 0.00075
# Epoch 100/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1044e-04 - val_loss: 8.0368e-04
#
# Epoch 00100: val_loss did not improve from 0.00075
# Epoch 101/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1082e-04 - val_loss: 7.8587e-04
#
# Epoch 00101: val_loss did not improve from 0.00075
# Epoch 102/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0891e-04 - val_loss: 8.1739e-04
#
# Epoch 00102: val_loss did not improve from 0.00075
# Epoch 103/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1084e-04 - val_loss: 7.9789e-04
#
# Epoch 00103: val_loss did not improve from 0.00075
# Epoch 104/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0998e-04 - val_loss: 8.1839e-04
#
# Epoch 00104: val_loss did not improve from 0.00075
# Epoch 105/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1041e-04 - val_loss: 8.0165e-04
#
# Epoch 00105: val_loss did not improve from 0.00075
# Epoch 106/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1101e-04 - val_loss: 8.2640e-04
#
# Epoch 00106: val_loss did not improve from 0.00075
# Epoch 107/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0942e-04 - val_loss: 7.8784e-04
#
# Epoch 00107: val_loss did not improve from 0.00075
# Epoch 108/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0523e-04 - val_loss: 8.0178e-04
#
# Epoch 00108: val_loss did not improve from 0.00075
# Epoch 109/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0817e-04 - val_loss: 7.5707e-04
#
# Epoch 00109: val_loss did not improve from 0.00075
# Epoch 110/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0873e-04 - val_loss: 7.9561e-04
#
# Epoch 00110: val_loss did not improve from 0.00075
# Epoch 111/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0521e-04 - val_loss: 8.3425e-04
#
# Epoch 00111: val_loss did not improve from 0.00075
# Epoch 112/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0625e-04 - val_loss: 8.1732e-04
#
# Epoch 00112: val_loss did not improve from 0.00075
# Epoch 113/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0327e-04 - val_loss: 7.6412e-04
#
# Epoch 00113: val_loss did not improve from 0.00075
# Epoch 114/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0297e-04 - val_loss: 7.7343e-04
#
# Epoch 00114: val_loss did not improve from 0.00075
# Epoch 115/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0334e-04 - val_loss: 7.7072e-04
#
# Epoch 00115: val_loss did not improve from 0.00075
# Epoch 116/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0606e-04 - val_loss: 8.0512e-04
#
# Epoch 00116: val_loss did not improve from 0.00075
# Epoch 117/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0219e-04 - val_loss: 7.8020e-04
#
# Epoch 00117: val_loss did not improve from 0.00075
# Epoch 118/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0258e-04 - val_loss: 8.0243e-04
#
# Epoch 00118: val_loss did not improve from 0.00075
# Epoch 119/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0002e-04 - val_loss: 7.8282e-04
#
# Epoch 00119: val_loss did not improve from 0.00075
# Epoch 120/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 9.8107e-05 - val_loss: 7.7348e-04
#
# Epoch 00120: val_loss did not improve from 0.00075
# Epoch 121/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.9280e-05 - val_loss: 7.7895e-04
#
# Epoch 00121: val_loss did not improve from 0.00075
# Epoch 122/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.8724e-05 - val_loss: 8.2119e-04
#
# Epoch 00122: val_loss did not improve from 0.00075
# Epoch 123/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5386e-05 - val_loss: 8.2015e-04
#
# Epoch 00123: val_loss did not improve from 0.00075
# Epoch 124/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5668e-05 - val_loss: 8.1925e-04
#
# Epoch 00124: val_loss did not improve from 0.00075
# Epoch 125/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.3292e-05 - val_loss: 7.6915e-04
#
# Epoch 00125: val_loss did not improve from 0.00075
# Epoch 126/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6102e-05 - val_loss: 7.9563e-04
#
# Epoch 00126: val_loss did not improve from 0.00075
# Epoch 127/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.3806e-05 - val_loss: 8.2052e-04
#
# Epoch 00127: val_loss did not improve from 0.00075
# Epoch 128/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2502e-05 - val_loss: 7.9652e-04
#
# Epoch 00128: val_loss did not improve from 0.00075
# Epoch 129/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.1723e-05 - val_loss: 8.1814e-04
#
# Epoch 00129: val_loss did not improve from 0.00075
# Epoch 130/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5088e-05 - val_loss: 7.8463e-04
#
# Epoch 00130: val_loss did not improve from 0.00075
# Epoch 131/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5734e-05 - val_loss: 7.9716e-04
#
# Epoch 00131: val_loss did not improve from 0.00075
# Epoch 132/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2457e-05 - val_loss: 7.8238e-04
#
# Epoch 00132: val_loss did not improve from 0.00075
# Epoch 133/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.3524e-05 - val_loss: 7.8049e-04
#
# Epoch 00133: val_loss did not improve from 0.00075
# Epoch 134/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.1541e-05 - val_loss: 7.7834e-04
#
# Epoch 00134: val_loss did not improve from 0.00075
# Epoch 135/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.1223e-05 - val_loss: 8.0688e-04
#
# Epoch 00135: val_loss did not improve from 0.00075
# Epoch 136/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0377e-05 - val_loss: 7.7732e-04
#
# Epoch 00136: val_loss did not improve from 0.00075
# Epoch 137/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.2626e-05 - val_loss: 8.0806e-04
#
# Epoch 00137: val_loss did not improve from 0.00075
# Epoch 138/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.3578e-05 - val_loss: 7.7617e-04
#
# Epoch 00138: val_loss did not improve from 0.00075
# Epoch 139/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0270e-05 - val_loss: 8.2208e-04
#
# Epoch 00139: val_loss did not improve from 0.00075
# Epoch 140/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 8.9228e-05 - val_loss: 8.0664e-04
#
# Epoch 00140: val_loss did not improve from 0.00075
# Epoch 141/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0123e-05 - val_loss: 8.0811e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0654e-05 - val_loss: 7.7807e-04
#
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7957e-05 - val_loss: 7.9771e-04
#
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.7012e-05 - val_loss: 7.6817e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8659e-05 - val_loss: 8.2615e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
# Epoch 146/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0712e-05 - val_loss: 7.9587e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8333e-05 - val_loss: 7.8959e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.5597e-05 - val_loss: 8.1185e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.5117e-05 - val_loss: 8.0045e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.5383e-05 - val_loss: 8.1102e-04
#
# Epoch 00150: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'Facial_Keypoints_Detection/test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
'''
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
'''


hist_model_aug = model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, nb_epoch = 20, callbacks=[checkpoint, hist], shuffle=True, validation_data=(train_X, points_train))
# Out:
# /Users/wanghsinhao/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /Users/wanghsinhao/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., steps_per_epoch=66, callbacks=[<keras.ca..., shuffle=True, validation_data=(array([[[..., epochs=20)`
#   if sys.path[0] == '':
# Epoch 1/20
# 66/66 [==============================] - 10s 157ms/step - loss: 0.0043 - val_loss: 0.0011
#
# Epoch 00001: val_loss did not improve from 0.00075
# Epoch 2/20
# 66/66 [==============================] - 11s 168ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00002: val_loss did not improve from 0.00075
# Epoch 3/20
# 66/66 [==============================] - 10s 157ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00003: val_loss did not improve from 0.00075
# Epoch 4/20
# 66/66 [==============================] - 11s 159ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00004: val_loss did not improve from 0.00075
# Epoch 5/20
# 66/66 [==============================] - 10s 154ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00005: val_loss did not improve from 0.00075
# Epoch 6/20
# 66/66 [==============================] - 11s 165ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00006: val_loss did not improve from 0.00075
# Epoch 7/20
# 66/66 [==============================] - 12s 176ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00007: val_loss did not improve from 0.00075
# Epoch 8/20
# 66/66 [==============================] - 11s 173ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00008: val_loss did not improve from 0.00075
# Epoch 9/20
# 66/66 [==============================] - 11s 174ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00009: val_loss did not improve from 0.00075
# Epoch 10/20
# 66/66 [==============================] - 10s 159ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00010: val_loss did not improve from 0.00075
# Epoch 11/20
# 66/66 [==============================] - 11s 162ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00075
# Epoch 12/20
# 66/66 [==============================] - 12s 179ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00075
# Epoch 13/20
# 66/66 [==============================] - 11s 169ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00075
# Epoch 14/20
# 66/66 [==============================] - 12s 178ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00075
# Epoch 15/20
# 66/66 [==============================] - 11s 173ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00075
# Epoch 16/20
# 66/66 [==============================] - 13s 201ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00075
# Epoch 17/20
# 66/66 [==============================] - 14s 206ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00075
# Epoch 18/20
# 66/66 [==============================] - 14s 219ms/step - loss: 0.0012 - val_loss: 0.0012
#
# Epoch 00018: val_loss did not improve from 0.00075
# Epoch 19/20
# 66/66 [==============================] - 12s 189ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00075
# Epoch 20/20
# 66/66 [==============================] - 12s 184ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00020: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 官方解答

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# improved from 0.00065 to 0.00063, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.9122e-04 - val_loss: 6.4386e-04
#
# Epoch 00033: val_loss did not improve from 0.00063
# Epoch 34/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.9000e-04 - val_loss: 6.4996e-04
#
# Epoch 00034: val_loss did not improve from 0.00063
# Epoch 35/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.8035e-04 - val_loss: 6.4369e-04
#
# Epoch 00035: val_loss did not improve from 0.00063
# Epoch 36/150
# 3424/3424 [==============================] - 16s 5ms/step - loss: 1.8131e-04 - val_loss: 6.3842e-04
#
# Epoch 00036: val_loss did not improve from 0.00063
# Epoch 37/150
# 3424/3424 [==============================] - 18s 5ms/step - loss: 1.8246e-04 - val_loss: 6.4314e-04
#
# Epoch 00037: val_loss did not improve from 0.00063
# Epoch 38/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 1.7558e-04 - val_loss: 6.3597e-04
#
# Epoch 00038: val_loss did not improve from 0.00063
# Epoch 39/150
# 3424/3424 [==============================] - 22s 7ms/step - loss: 1.6952e-04 - val_loss: 6.4792e-04
#
# Epoch 00039: val_loss did not improve from 0.00063
# Epoch 40/150
# 3424/3424 [==============================] - 19s 6ms/step - loss: 1.6792e-04 - val_loss: 6.3322e-04
#
# Epoch 00040: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 41/150
# 3424/3424 [==============================] - 22s 6ms/step - loss: 1.6427e-04 - val_loss: 6.2683e-04
#
# Epoch 00041: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 42/150
# 3424/3424 [==============================] - 22s 6ms/step - loss: 1.6287e-04 - val_loss: 6.2937e-04
#
# Epoch 00042: val_loss did not improve from 0.00063
# Epoch 43/150
# 3424/3424 [==============================] - 16s 5ms/step - loss: 1.6244e-04 - val_loss: 6.5145e-04
#
# Epoch 00043: val_loss did not improve from 0.00063
# Epoch 44/150
# 3424/3424 [==============================] - 16s 5ms/step - loss: 1.5881e-04 - val_loss: 6.6853e-04
#
# Epoch 00044: val_loss did not improve from 0.00063
# Epoch 45/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.5465e-04 - val_loss: 6.2528e-04
#
# Epoch 00045: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 46/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.5271e-04 - val_loss: 6.2262e-04
#
# Epoch 00046: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 47/150
# 3424/3424 [==============================] - 16s 5ms/step - loss: 1.5026e-04 - val_loss: 6.0309e-04
#
# Epoch 00047: val_loss improved from 0.00062 to 0.00060, saving model to best_weights_augment.h5
# Epoch 48/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.4868e-04 - val_loss: 6.1661e-04
#
# Epoch 00048: val_loss did not improve from 0.00060
# Epoch 49/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4965e-04 - val_loss: 6.3538e-04
#
# Epoch 00049: val_loss did not improve from 0.00060
# Epoch 50/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4419e-04 - val_loss: 6.0740e-04
#
# Epoch 00050: val_loss did not improve from 0.00060
# Epoch 51/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4257e-04 - val_loss: 6.1196e-04
#
# Epoch 00051: val_loss did not improve from 0.00060
# Epoch 52/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4259e-04 - val_loss: 6.2818e-04
#
# Epoch 00052: val_loss did not improve from 0.00060
# Epoch 53/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3875e-04 - val_loss: 6.2274e-04
#
# Epoch 00053: val_loss did not improve from 0.00060
# Epoch 54/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4003e-04 - val_loss: 6.6797e-04
#
# Epoch 00054: val_loss did not improve from 0.00060
# Epoch 55/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3687e-04 - val_loss: 6.2252e-04
#
# Epoch 00055: val_loss did not improve from 0.00060
# Epoch 56/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.3530e-04 - val_loss: 6.2465e-04
#
# Epoch 00056: val_loss did not improve from 0.00060
# Epoch 57/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3604e-04 - val_loss: 6.1750e-04
#
# Epoch 00057: val_loss did not improve from 0.00060
# Epoch 58/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.3157e-04 - val_loss: 6.3156e-04
#
# Epoch 00058: val_loss did not improve from 0.00060
# Epoch 59/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2837e-04 - val_loss: 6.3608e-04
#
# Epoch 00059: val_loss did not improve from 0.00060
# Epoch 60/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.3085e-04 - val_loss: 6.3079e-04
#
# Epoch 00060: val_loss did not improve from 0.00060
# Epoch 61/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.2825e-04 - val_loss: 6.1992e-04
#
# Epoch 00061: val_loss did not improve from 0.00060
# Epoch 62/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2669e-04 - val_loss: 6.1300e-04
#
# Epoch 00062: val_loss did not improve from 0.00060
# Epoch 63/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2333e-04 - val_loss: 6.0909e-04
#
# Epoch 00063: val_loss did not improve from 0.00060
# Epoch 64/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.2880e-04 - val_loss: 6.1538e-04
#
# Epoch 00064: val_loss did not improve from 0.00060
# Epoch 65/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.2474e-04 - val_loss: 6.2141e-04
#
# Epoch 00065: val_loss did not improve from 0.00060
# Epoch 66/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.2238e-04 - val_loss: 6.0295e-04
#
# Epoch 00066: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 67/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.2217e-04 - val_loss: 6.1264e-04
#
# Epoch 00067: val_loss did not improve from 0.00060
# Epoch 68/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.1638e-04 - val_loss: 6.1036e-04
#
# Epoch 00068: val_loss did not improve from 0.00060
# Epoch 69/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.1895e-04 - val_loss: 6.4014e-04
#
# Epoch 00069: val_loss did not improve from 0.00060
# Epoch 70/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.1620e-04 - val_loss: 6.1775e-04
#
# Epoch 00070: val_loss did not improve from 0.00060
# Epoch 71/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.1424e-04 - val_loss: 6.1101e-04
#
# Epoch 00071: val_loss did not improve from 0.00060
# Epoch 72/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.1427e-04 - val_loss: 6.4998e-04
#
# Epoch 00072: val_loss did not improve from 0.00060
# Epoch 73/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1428e-04 - val_loss: 6.1482e-04
#
# Epoch 00073: val_loss did not improve from 0.00060
# Epoch 74/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1404e-04 - val_loss: 6.1295e-04
#
# Epoch 00074: val_loss did not improve from 0.00060
# Epoch 75/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.1109e-04 - val_loss: 6.1194e-04
#
# Epoch 00075: val_loss did not improve from 0.00060
# Epoch 76/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.1168e-04 - val_loss: 6.0478e-04
#
# Epoch 00076: val_loss did not improve from 0.00060
# Epoch 77/150
# 3424/3424 [==============================] - 15s 5ms/step - loss: 1.1356e-04 - val_loss: 6.3479e-04
#
# Epoch 00077: val_loss did not improve from 0.00060
# Epoch 78/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.1058e-04 - val_loss: 6.0989e-04
#
# Epoch 00078: val_loss did not improve from 0.00060
# Epoch 79/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.0850e-04 - val_loss: 6.4525e-04
#
# Epoch 00079: val_loss did not improve from 0.00060
# Epoch 80/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.0639e-04 - val_loss: 6.4151e-04
#
# Epoch 00080: val_loss did not improve from 0.00060
# Epoch 81/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.0460e-04 - val_loss: 6.4181e-04
#
# Epoch 00081: val_loss did not improve from 0.00060
# Epoch 82/150
# 3424/3424 [==============================] - 16s 5ms/step - loss: 1.0316e-04 - val_loss: 6.2558e-04
#
# Epoch 00082: val_loss did not improve from 0.00060
# Epoch 83/150
# 3424/3424 [==============================] - 15s 5ms/step - loss: 1.0172e-04 - val_loss: 6.0833e-04
#
# Epoch 00083: val_loss did not improve from 0.00060
# Epoch 84/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0303e-04 - val_loss: 6.1755e-04
#
# Epoch 00084: val_loss did not improve from 0.00060
# Epoch 85/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0249e-04 - val_loss: 6.2180e-04
#
# Epoch 00085: val_loss did not improve from 0.00060
# Epoch 86/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0054e-04 - val_loss: 6.2870e-04
#
# Epoch 00086: val_loss did not improve from 0.00060
# Epoch 87/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0106e-04 - val_loss: 6.3550e-04
#
# Epoch 00087: val_loss did not improve from 0.00060
# Epoch 88/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0072e-04 - val_loss: 6.1361e-04
#
# Epoch 00088: val_loss did not improve from 0.00060
# Epoch 89/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.9743e-05 - val_loss: 6.2841e-04
#
# Epoch 00089: val_loss did not improve from 0.00060
# Epoch 90/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.9506e-05 - val_loss: 6.1067e-04
#
# Epoch 00090: val_loss did not improve from 0.00060
# Epoch 91/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.8441e-05 - val_loss: 6.0171e-04
#
# Epoch 00091: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 92/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 9.8677e-05 - val_loss: 6.1235e-04
#
# Epoch 00092: val_loss did not improve from 0.00060
# Epoch 93/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.7465e-05 - val_loss: 6.1963e-04
#
# Epoch 00093: val_loss did not improve from 0.00060
# Epoch 94/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0011e-04 - val_loss: 6.2838e-04
#
# Epoch 00094: val_loss did not improve from 0.00060
# Epoch 95/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.7006e-05 - val_loss: 6.0710e-04
#
# Epoch 00095: val_loss did not improve from 0.00060
# Epoch 96/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.5956e-05 - val_loss: 6.5704e-04
#
# Epoch 00096: val_loss did not improve from 0.00060
# Epoch 97/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.6849e-05 - val_loss: 6.0266e-04
#
# Epoch 00097: val_loss did not improve from 0.00060
# Epoch 98/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.5466e-05 - val_loss: 6.1757e-04
#
# Epoch 00098: val_loss did not improve from 0.00060
# Epoch 99/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.2731e-05 - val_loss: 6.2974e-04
#
# Epoch 00099: val_loss did not improve from 0.00060
# Epoch 100/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.1828e-05 - val_loss: 6.3248e-04
#
# Epoch 00100: val_loss did not improve from 0.00060
# Epoch 101/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.1735e-05 - val_loss: 6.0966e-04
#
# Epoch 00101: val_loss did not improve from 0.00060
# Epoch 102/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.1615e-05 - val_loss: 6.2034e-04
#
# Epoch 00102: val_loss did not improve from 0.00060
# Epoch 103/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.2526e-05 - val_loss: 6.2670e-04
#
# Epoch 00103: val_loss did not improve from 0.00060
# Epoch 104/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.1372e-05 - val_loss: 6.2051e-04
#
# Epoch 00104: val_loss did not improve from 0.00060
# Epoch 105/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.1213e-05 - val_loss: 6.1850e-04
#
# Epoch 00105: val_loss did not improve from 0.00060
# Epoch 106/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.1792e-05 - val_loss: 6.0318e-04
#
# Epoch 00106: val_loss did not improve from 0.00060
# Epoch 107/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.2360e-05 - val_loss: 6.3280e-04
#
# Epoch 00107: val_loss did not improve from 0.00060
# Epoch 108/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.1503e-05 - val_loss: 6.2872e-04
#
# Epoch 00108: val_loss did not improve from 0.00060
# Epoch 109/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.9332e-05 - val_loss: 6.1036e-04
#
# Epoch 00109: val_loss did not improve from 0.00060
# Epoch 110/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.0120e-05 - val_loss: 6.0907e-04
#
# Epoch 00110: val_loss did not improve from 0.00060
# Epoch 111/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.8483e-05 - val_loss: 6.0901e-04
#
# Epoch 00111: val_loss did not improve from 0.00060
# Epoch 112/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.8032e-05 - val_loss: 6.0680e-04
#
# Epoch 00112: val_loss did not improve from 0.00060
# Epoch 113/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.6582e-05 - val_loss: 6.0145e-04
#
# Epoch 00113: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 114/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.7568e-05 - val_loss: 6.0909e-04
#
# Epoch 00114: val_loss did not improve from 0.00060
# Epoch 115/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.7466e-05 - val_loss: 6.3315e-04
#
# Epoch 00115: val_loss did not improve from 0.00060
# Epoch 116/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.6729e-05 - val_loss: 6.2165e-04
#
# Epoch 00116: val_loss did not improve from 0.00060
# Epoch 117/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.7736e-05 - val_loss: 6.2332e-04
#
# Epoch 00117: val_loss did not improve from 0.00060
# Epoch 118/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.0248e-05 - val_loss: 6.3334e-04
#
# Epoch 00118: val_loss did not improve from 0.00060
# Epoch 119/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.0258e-05 - val_loss: 6.2909e-04
#
# Epoch 00119: val_loss did not improve from 0.00060
# Epoch 120/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.6835e-05 - val_loss: 6.2131e-04
#
# Epoch 00120: val_loss did not improve from 0.00060
# Epoch 121/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.5632e-05 - val_loss: 6.3279e-04
#
# Epoch 00121: val_loss did not improve from 0.00060
# Epoch 122/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.6418e-05 - val_loss: 6.4624e-04
#
# Epoch 00122: val_loss did not improve from 0.00060
# Epoch 123/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.6364e-05 - val_loss: 6.0578e-04
#
# Epoch 00123: val_loss did not improve from 0.00060
# Epoch 124/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.4199e-05 - val_loss: 6.2012e-04
#
# Epoch 00124: val_loss did not improve from 0.00060
# Epoch 125/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.5596e-05 - val_loss: 6.1320e-04
#
# Epoch 00125: val_loss did not improve from 0.00060
# Epoch 126/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.2807e-05 - val_loss: 6.1090e-04
#
# Epoch 00126: val_loss did not improve from 0.00060
# Epoch 127/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 8.6166e-05 - val_loss: 6.1709e-04
#
# Epoch 00127: val_loss did not improve from 0.00060
# Epoch 128/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.2133e-05 - val_loss: 6.0871e-04
#
# Epoch 00128: val_loss did not improve from 0.00060
# Epoch 129/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.5417e-05 - val_loss: 6.2030e-04
#
# Epoch 00129: val_loss did not improve from 0.00060
# Epoch 130/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.3859e-05 - val_loss: 6.1268e-04
#
# Epoch 00130: val_loss did not improve from 0.00060
# Epoch 131/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.2714e-05 - val_loss: 5.9955e-04
#
# Epoch 00131: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 132/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.3795e-05 - val_loss: 6.1282e-04
#
# Epoch 00132: val_loss did not improve from 0.00060
# Epoch 133/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.2658e-05 - val_loss: 6.4323e-04
#
# Epoch 00133: val_loss did not improve from 0.00060
# Epoch 134/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.2165e-05 - val_loss: 6.1323e-04
#
# Epoch 00134: val_loss did not improve from 0.00060
# Epoch 135/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.0479e-05 - val_loss: 6.3214e-04
#
# Epoch 00135: val_loss did not improve from 0.00060
# Epoch 136/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.0885e-05 - val_loss: 6.2019e-04
#
# Epoch 00136: val_loss did not improve from 0.00060
# Epoch 137/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.1092e-05 - val_loss: 6.3025e-04
#
# Epoch 00137: val_loss did not improve from 0.00060
# Epoch 138/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.1439e-05 - val_loss: 6.3219e-04
#
# Epoch 00138: val_loss did not improve from 0.00060
# Epoch 139/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.0369e-05 - val_loss: 6.1470e-04
#
# Epoch 00139: val_loss did not improve from 0.00060
# Epoch 140/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 7.9915e-05 - val_loss: 6.2731e-04
#
# Epoch 00140: val_loss did not improve from 0.00060
# Epoch 141/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 7.8539e-05 - val_loss: 6.0879e-04
#
# Epoch 00141: val_loss did not improve from 0.00060
# Epoch 142/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 7.9226e-05 - val_loss: 6.2775e-04
#
# Epoch 00142: val_loss did not improve from 0.00060
# Epoch 143/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 7.8974e-05 - val_loss: 6.0756e-04
#
# Epoch 00143: val_loss did not improve from 0.00060
# Epoch 144/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.0113e-05 - val_loss: 6.3032e-04
#
# Epoch 00144: val_loss did not improve from 0.00060
# Epoch 145/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 7.8881e-05 - val_loss: 6.2369e-04
#
# Epoch 00145: val_loss did not improve from 0.00060
# Epoch 146/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 7.8882e-05 - val_loss: 6.1907e-04
#
# Epoch 00146: val_loss did not improve from 0.00060
# Epoch 147/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 7.9423e-05 - val_loss: 6.2200e-04
#
# Epoch 00147: val_loss did not improve from 0.00060
# Epoch 148/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.0287e-05 - val_loss: 6.3137e-04
#
# Epoch 00148: val_loss did not improve from 0.00060
# Epoch 149/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 7.9043e-05 - val_loss: 6.3508e-04
#
# Epoch 00149: val_loss did not improve from 0.00060
# Epoch 150/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 7.8715e-05 - val_loss: 6.3580e-04
#
# Epoch 00150: val_loss did not improve from 0.00060

# %%
# loss 值的圖
plt.title('Optimizer:Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Train Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
